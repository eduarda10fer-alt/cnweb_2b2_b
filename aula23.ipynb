# %% [markdown]
# <a href="https://colab.research.google.com/github/eduarda10fer-alt/cnweb_2b2_b/blob/main/aula23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Exemplo de serviço

# %%
def soma(a, b):
  return (a+b)

# %%
soma(8, 45)
# Out:
# 53

# %% [markdown]
# #sistema de equações

# %%
import math

def eq2grau(a, b, c):
 delta = b**2 - 4*a*c

 if(delta < 0):
  return 'equação sem solução'
  else:
   x1 =(-b + match.sqrt(delta)) / (2*a)
   x2 =(-b - match.sqrt(delta)) / (2*a)
   return x1, x2
# Out:
#   File "/tmp/ipykernel_8790/3648175281.py", line 6
#     if(delta == < 0):
#                 ^
# SyntaxError: invalid syntax

# %%
print(eq2grau(1, -3, 2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_8790/2522592806.py in <cell line: 0>()
# ----> 1 print(eq2grau(1, -3, 2))
#
# NameError: name 'eq2grau' is not defined
