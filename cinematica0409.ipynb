# %% [markdown]
# <a href="https://colab.research.google.com/github/eduarda10fer-alt/cnweb_2b2_b/blob/main/cinematica0409.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Formula da Velocidade Média

# %%
def calcVelMedia(deltaS, deltaT):
  velMedia = (deltaS / deltaT)
  return velMedia

# %% [markdown]
# teste de serviço: velocidade media

# %%
print('Velocidade Média: ',calcVelMedia(50, 4))
# Out:
# Velocidade Média:  12.5

# %% [markdown]
# # fórmula da aceleração

# %%
def calcular_aceleracao(v_inicial, v_final, t_inicial, t_final):
    a= (v_final - v_inicial) / (t_final - t_inicial)
    return a

# %% [markdown]
# testes

# %%
print("aceleração:",calcular_aceleracao(10, 30, 12, 25))
# Out:
# aceleração: 1.5384615384615385

# %% [markdown]
# # Fórmulas do Movimento Uniforme (MU)

# %%
def movimento_uniforme(s0, v, t):
  return s0 + (v * t)

# %% [markdown]
# testes

# %%
print("posicao final:", movimento_uniforme(0, 15, 5 ))
# Out:
# posicao final: 75

# %% [markdown]
# ## Função horária do deslocamento

# %%
def funcao_deslocamento()

# %% [markdown]
# # Fórmulas do Movimento Uniformemente Variado (MUV)

# %% [markdown]
# ## Função horária da posição

# %% [markdown]
# ## Equação de Torricelli

# %%
import math
def caLctorricelli(vZero, acel, desloc):
  t = 2 * acel * desloc
  vFinal = t + VZero
  res = round(math.sqrt(vFinal), 2)
  return res

# %% [markdown]
# # Fórmula do movimento vertical

# %% [markdown]
# ## Equação de Torricelli para lançamento vertical

# %%
def calcTorricelli(vZero, grav, alt):
  vFinal1 = (vZero ** 2) - (2 * grav * alt)
  vFinal1 = (vZero ** 2) + (2 * grav * alt)
  return vFinal1,vFinal2

# %% [markdown]
# testes

# %%
print("Torricelli vertical [subindo], [Descendo]" ,calcTorricelliver (50, 10, 100))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_18188/3100799277.py in <cell line: 0>()
# ----> 1 print("Torricelli vertical [subindo], [Descendo]" ,calcTorricelliver (50, 10, 100))
#
# NameError: name 'calcTorricelliver' is not defined

# %% [markdown]
# ## Velocidade vertical em função do tempo

# %% [markdown]
# ## Posição vertical em função do tempo
